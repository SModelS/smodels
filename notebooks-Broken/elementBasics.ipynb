# %%
import sys
sys.path.append('../')
import networkx as nx
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout
from smodels.theory.theorySMS import TheorySMS
from smodels.experiment.expSMS import ExpSMS
from smodels.particlesLoader import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.theory.model import Model
from smodels.tools.physicsUnits import GeV

# %% [markdown]
# ### Create element from old string format

# %%
elementStr = "[[['e+','e-'],['jet','jet']],[['mu-','nu'],['ta+']]]"
el = ExpSMS.from_string(elementStr)
print(el)
# Out:
# (PV > anyBSM(1),anyBSM(2)), (anyBSM(1) > anyBSM(3),e+,e-), (anyBSM(2) > anyBSM(4),mu-,nu), (anyBSM(3) > jet,jet,MET), (anyBSM(4) > ta+,MET)

# %%
elementStr = "[[['e+','e-'],['jet','jet']],[['mu-','nu'],['ta+']]]"
el = ExpSMS.from_string(elementStr)
el.draw()
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 1110101101000110101101010000
# Process= (PV > anyBSM(1),anyBSM(2)), (anyBSM(1) > anyBSM(3),e+,e-), (anyBSM(2) > anyBSM(4),mu-,nu), (anyBSM(3) > jet,jet,MET), (anyBSM(4) > ta+,MET)
# [(PV, 0), (anyBSM, 1), (anyBSM, 2), (anyBSM, 3), (anyBSM, 4), (e+, 5), (e-, 6), (jet, 7), (jet, 8), (MET, 9), (mu-, 10), (nu, 11), (ta+, 12), (MET, 13)]
# [[PV, anyBSM], [PV, anyBSM], [anyBSM, anyBSM], [anyBSM, e+], [anyBSM, e-], [anyBSM, jet], [anyBSM, jet], [anyBSM, MET], [anyBSM, anyBSM], [anyBSM, mu-], [anyBSM, nu], [anyBSM, ta+], [anyBSM, MET]]

# %%
stringEl = "[ [['e-','nu'], ['jet','jet'] ], [ ['L','nu'] ] ]"
finalStates=['MET','HSCP']
intermediateStates=[['squark','gluino'],['squark']]
el = ExpSMS.from_string(stringEl,finalState=finalStates,intermediateState=intermediateStates)
el.draw()
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 111010100110101101010000
# Process= (PV > squark(1),squark(2)), (squark(1) > gluino(3),e-,nu), (squark(2) > L,nu,HSCP), (gluino(3) > jet,jet,MET)
# [(PV, 0), (squark, 1), (gluino, 2), (squark, 3), (e-, 4), (nu, 5), (jet, 6), (jet, 7), (MET, 8), (L, 9), (nu, 10), (HSCP, 11)]
# [[PV, squark], [PV, squark], [squark, gluino], [squark, e-], [squark, nu], [gluino, jet], [gluino, jet], [gluino, MET], [squark, L], [squark, nu], [squark, HSCP]]

# %% [markdown]
# ### Create element from new string format

# %%
elementStr = str(el)
print(elementStr)
# Out:
# (PV > squark(1),squark(2)), (squark(1) > gluino(3),e-,nu), (squark(2) > L,nu,HSCP), (gluino(3) > jet,jet,MET)

# %%
el = ExpSMS.from_string(elementStr)
el.draw(nodeScale=3)
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 111010100110101101010000
# Process= (PV > squark(1),squark(2)), (squark(1) > gluino(3),e-,nu), (squark(2) > L,nu,HSCP), (gluino(3) > jet,jet,MET)
# [(PV, 0), (squark, 1), (squark, 2), (gluino, 3), (e-, 4), (nu, 5), (L, 6), (nu, 7), (HSCP, 8), (jet, 9), (jet, 10), (MET, 11)]
# [[PV, squark], [PV, squark], [squark, gluino], [squark, e-], [squark, nu], [squark, L], [squark, nu], [squark, HSCP], [gluino, jet], [gluino, jet], [gluino, MET]]

# %%
elementStr = proc = "(PV > Z'(1)), (Z'(1) > e+, e-)"
el = ExpSMS.from_string(elementStr)
el.draw(nodeScale=10)
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 11101000
# Process= (PV > Z'(1)), (Z'(1) > e+,e-)
# [(PV, 0), (Z', 1), (e+, 2), (e-, 3)]
# [[PV, Z'], [Z', e+], [Z', e-]]

# %%
elementStr = proc = "(PV > Z'(1)), (Z'(1) > X(2), h), (X(2) > j,j)"
el = ExpSMS.from_string(elementStr)
el.draw(nodeScale=10)
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 111011010000
# Process= (PV > Z'(1)), (Z'(1) > X(2),h), (X(2) > j,j)
# [(PV, 0), (Z', 1), (X, 2), (h, 3), (j, 4), (j, 5)]
# [[PV, Z'], [Z', X], [Z', h], [X, j], [X, j]]

# %%
elementStr = proc = "(PV > q,LQ(1)), (LQ(1) > e+, j)"
el = ExpSMS.from_string(elementStr)
el.draw(nodeScale=10)
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 1101101000
# Process= (PV > LQ(1),q), (LQ(1) > e+,j)
# [(PV, 0), (LQ, 1), (q, 2), (e+, 3), (j, 4)]
# [[PV, LQ], [PV, q], [LQ, e+], [LQ, j]]

# %%
elementStr = proc = '(PV > gluino(1),squark(2)), (gluino(1) > X(3),X(4),jet), (squark(2) > HSCP,L,nu), (X(3) > nu,nu), (X(4) > MET,e-)'
el = ExpSMS.from_string(elementStr)
el.draw()
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 11101010011011010011010000
# Process= (PV > gluino(1),squark(2)), (gluino(1) > X(3),X(4),jet), (squark(2) > HSCP,L,nu), (X(3) > nu,nu), (X(4) > MET,e-)
# [(PV, 0), (gluino, 1), (squark, 2), (X, 3), (X, 4), (jet, 5), (HSCP, 6), (L, 7), (nu, 8), (nu, 9), (nu, 10), (MET, 11), (e-, 12)]
# [[PV, gluino], [PV, squark], [gluino, X], [gluino, X], [gluino, jet], [squark, HSCP], [squark, L], [squark, nu], [X, nu], [X, nu], [X, MET], [X, e-]]

# %%
print(el)
# Out:
# (PV > gluino(1),squark(2)), (gluino(1) > X(3),X(4),jet), (squark(2) > HSCP,L,nu), (X(3) > nu,nu), (X(4) > MET,e-)

# %% [markdown]
# ### Create element using a model

# %%
slhafile = '../inputFiles/slha/lightEWinos.slha'
model = Model(BSMparticles=BSMList, SMparticles=SMList)
model.updateParticles(inputFile=slhafile)

# %%
stringEl = "(PV > su_L(1),su_L~(2)), (su_L(1) > gluino(3),e-,nu), (su_L~(2) > C1+,d), (gluino(3) > N1,u,u~)"
el = ExpSMS.from_string(stringEl,model=model)
el.draw()
print('Name=',el.canonName,'\nProcess=',el)
print([(n,nIndex) for n,nIndex in zip(el.nodes,el.nodeIndices)])
print(el.edges)
# Out:
# Name= 1110100110101101010000
# Process= (PV > su_L(1),su_L~(2)), (su_L(1) > gluino(3),e-,nu), (su_L~(2) > C1+,q), (gluino(3) > N1,q,q)
# [(PV, 0), (su_L, 1), (su_L~, 2), (gluino, 3), (e-, 4), (nu, 5), (C1+, 6), (q, 7), (N1, 8), (q, 9), (q, 10)]
# [[PV, su_L], [PV, su_L~], [su_L, gluino], [su_L, e-], [su_L, nu], [su_L~, C1+], [su_L~, q], [gluino, N1], [gluino, q], [gluino, q]]

# %% [markdown]
# #### Draw tree using distinct property for labels

# %%
el.draw(nodeScale=4,labelAttr='isSM')

# %%
el.draw(nodeScale=4,labelAttr='mass',attrUnit=GeV)

# %%
el.draw(nodeScale=5,labelAttr='node')

# %% [markdown]
# #### Convert to old bracket notation

# %%
elB,finalState,intermediateState = el.treeToBrackets()
print(elB)
print(finalState)
print(intermediateState)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 elB,finalState,intermediateState = el.treeToBrackets()
#       2 print(elB)
#       3 print(finalState)
#
# File ~/smodels-graphs/notebooks-Broken/../smodels/tools/genericSMS.py:482, in GenericSMS.treeToBrackets(self)
#     471 def treeToBrackets(self):
#     472     """
#     473     Convert the Tree to a nested list with the Z2 even
#     474     final states. The Z2 odd final states (e.g. 'MET', 'HSCP') are
#    (...)
#     479              (e.g. [[['e-','mu'],['L']],[['jet']]])
#     480     """
# --> 482     branches = [self.nodesMapping[b] for b in self.successors[self.root.node]]
#     483     finalState = []
#     484     intermediateState = []
#
# AttributeError: 'ExpSMS' object has no attribute 'successors'

# %%
stringEl = "(PV > N1,C1+(1)), (C1+(1) > N1,u,d)"
el = Element(info=stringEl,model=model)
el.drawTree(nodeScale=3)
print([(n,n.node) for n in el.tree.nodes])
print(el.tree.edges)

# %%
elB,finalState,intermediateState = el.tree.treeToBrackets()
print(elB)
print(finalState)
print(intermediateState)

# %% [markdown]
# ### Get attributes from nodes

# %%
el.drawTree()
print([(n,n.node) for n in el.tree.nodes])
print(el.tree.edges)

# %%
masses = list(zip(el.tree.nodes,el.mass))
print(masses)

# %%
pdgs = list(zip(el.tree.nodes,el.pdg))
print(pdgs)

# %%
Z2parity = list(zip(el.tree.nodes,el.isSM))
print(Z2parity)

# %%
# Final states:
print(el.getFinalStates())
