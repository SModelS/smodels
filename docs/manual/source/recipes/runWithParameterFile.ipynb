# %% [markdown]
# # How To: Run SModelS using a parameter file

# %%
# Set up the path to SModelS installation folder
import sys; sys.path.append("."); import smodels_paths

# %%
# Import those parts of smodels that are needed for this exercise
from smodels.installation import installDirectory, version
from smodels.tools import modelTester
from smodels.tools import crashReport
from smodels.tools import smodelsLogging
from smodels.tools import runtime
from smodels import particlesLoader
from imp import reload

# %%
#Define the SLHA file name
filename="inputFiles/slha/gluino_squarks.slha"
#Define the parameter file
parameterFile="../images/parameters.ini"

# %%
#Read and check parameter file, exit parameterFile does not exist
parser = modelTester.getParameters(parameterFile)
#Display defined options:
for section in parser.sections():
    print(section)
    for option in parser.options(section):
        print('  ',option,'=',parser.get(section,option))
# Out:
# options
#    checkinput = True
#    doinvisible = True
#    docompress = True
#    computestatistics = True
#    testcoverage = True
#    combinesrs = False
# particles
#    model = share.models.mssm
# parameters
#    sigmacut = 0.01
#    minmassgap = 5.
#    maxcond = 0.2
#    ncpus = 1
# database
#    path = http://smodels.hephy.at/database/official200
#    discardzeroes = True
#    analyses = all
#    txnames = all
#    dataselector = all
# printer
#    outputtype = summary,stdout
# stdout-printer
#    printdatabase = False
#    addanainfo = False
#    printdecomp = False
#    addelementinfo = False
#    printextendedresults = False
#    addcoverageid = False
# summary-printer
#    expandedsummary = True
# python-printer
#    addelementlist = False
#    addtxweights = False
# xml-printer
#    addelementlist = False
#    addtxweights = False

# %%
#Change option:
parser.set('printer','outputtype','summary')

# %%
#Determine particles module from ini file, if necessary """
if parser.has_option("particles","model"):
    runtime.modelFile = parser.get( "particles", "model" )
    reload(particlesLoader)

#Load the database defined in the parameters file, exit if not found """
database, databaseVersion = modelTester.loadDatabase(parser,db=None)
listOfExpRes = modelTester.loadDatabaseResults(parser, database)
# Out:
# loading >...................................................done.

# %%
#Set local dir as output folder:
outputDir = './'
#run SModelS with input file:
output = modelTester.testPoint(filename, outputDir, parser, databaseVersion,listOfExpRes)
# Out:
# WARNING in printer.setOutPutFile() in 537: Removing old output file ./gluino_squarks.slha.smodels

# %% [markdown]
# [Download output](./gluino_squarks.slha.smodels)

# %% [markdown]
# ### Display output:

# %%
# %load './gluino_squarks.slha.smodels'
Input status: 1
Decomposition output status: 1 #decomposition was successful
# Input File: inputFiles/slha/gluino_squarks.slha
# maxcond = 0.2
# minmassgap = 5.
# ncpus = 1
# sigmacut = 0.01
# Database version: 2.0.0rc1
================================================================================
#Analysis  Sqrts  Cond_Violation  Theory_Value(fb)  Exp_limit(fb)  r  r_expected

     CMS-SUS-16-036  1.30E+01    0.0  1.169E+01  7.683E+00  1.521E+00  N/A
 Signal Region:  (UL)
 Txnames:  T2
--------------------------------------------------------------------------------
     CMS-SUS-16-033  1.30E+01    0.0  1.169E+01  8.639E+00  1.353E+00  N/A
 Signal Region:  (UL)
 Txnames:  T2
--------------------------------------------------------------------------------
     CMS-SUS-16-033  1.30E+01    0.0  7.530E+00  6.785E+00  1.110E+00  N/A
 Signal Region:  (UL)
 Txnames:  T1
--------------------------------------------------------------------------------
     CMS-SUS-16-036  1.30E+01    0.0  7.530E+00  9.298E+00  8.098E-01  N/A
 Signal Region:  (UL)
 Txnames:  T1
--------------------------------------------------------------------------------
     CMS-SUS-13-019  8.00E+00    0.0  1.970E+00  3.759E+00  5.241E-01  N/A
 Signal Region:  (UL)
 Txnames:  T2
--------------------------------------------------------------------------------
 ATLAS-SUSY-2013-02  8.00E+00    0.0  6.661E+00  1.718E+01  3.876E-01  N/A
 Signal Region:  (UL)
 Txnames:  T6WW
--------------------------------------------------------------------------------
 ATLAS-SUSY-2013-02  8.00E+00    0.0  6.270E-01  1.818E+00  3.449E-01  4.146E-01
 Signal Region:  SR2jt
 Txnames:  T1, T2
 Chi2, Likelihood =  1.302E-01  1.276E-03
--------------------------------------------------------------------------------
 ATLAS-SUSY-2013-02  8.00E+00    0.0  1.970E+00  6.096E+00  3.232E-01  N/A
 Signal Region:  (UL)
 Txnames:  T2
--------------------------------------------------------------------------------
     CMS-SUS-13-012  8.00E+00    0.0
-04  N/A
 Signal Region:  (UL)
 Txnames:  T1tttt
--------------------------------------------------------------------------------
     CMS-SUS-12-028  8.00E+00    0.0  3.074E-03  3.606E+01  8.524E-05  1.165E-04
 Signal Region:  (UL)
 Txnames:  T1tttt

 
================================================================================
The highest r value is = 1.5212733123965427

Total missing topology cross section (fb):  3.065E+03
Total cross section where we are outside the mass grid (fb):  1.499E+00
Total cross section with longlived decays (fb):  0.000E+00
Total cross section with displaced decays (fb):  0.000E+00
Total cross section with MET decays (fb):  3.065E+03

Full information on unconstrained cross sections
================================================================================
Missing topologies with the highest cross sections (up to 10):
Sqrts (TeV)   Weight (fb)                  Element description
 13.0          1.482E+02    #        [[[jet],[W]],[[jet,jet],[W]]]  (prompt,prompt)
 13.0          1.445E+02    # [[[jet,jet],[W]],[[jet],[jet,jet],[W]]]  (prompt,prompt)
 13.0          1.047E+02    #        [[[b,t],[W]],[[jet,jet],[W]]]  (prompt,prompt)
 13.0          8.754E+01    #            [[[jet]],[[jet,jet],[W]]]  (prompt,prompt)
 13.0          8.654E+01    # [[[jet,jet],[W]],[[jet,jet],[higgs]]]  (prompt,prompt)
 13.0          7.520E+01    #            [[[jet],[W]],[[b,t],[W]]]  (prompt,prompt)
 13.0          7.333E+01    #  [[[jet,jet],[W]],[[jet],[b,t],[W]]]  (prompt,prompt)
 13.0          7.333E+01    #  [[[b,t],[W]],[[jet],[jet,jet],[W]]]  (prompt,prompt)
 13.0          6.576E+01    #  [[[jet],[W]],[[jet],[jet,jet],[W]]]  (prompt,prompt)
 13.0          6.214E+01    #    [[[jet],[W]],[[jet,jet],[higgs]]]  (prompt,prompt)
================================================================================
Contributions outside the mass grid (up to 10):
Sqrts (TeV)   Weight (fb)                  Element description
 13.0          1.438E+00    #                [[[t],[W]],[[t],[W]]]  (prompt,prompt)
 13.0          2.921E-02    #                [[[b],[W]],[[b],[W]]]  (prompt,prompt)
 13.0          1.872E-02    #                    [[[W]],[[higgs]]]  (prompt,prompt)
 13.0          1.335E-02    #            [[[jet],[W]],[[jet],[W]]]  (prompt,prompt)
================================================================================
No long-lived decays
================================================================================
No displaced decays
================================================================================
Missing topos: MET decays (up to 10 entries), sqrts = 13 TeV:
Sqrts (TeV)   Weight (fb)                  Element description
 13.0          1.482E+02    #        [[[jet],[W]],[[jet,jet],[W]]]  (prompt,prompt)
 13.0          1.445E+02    # [[[jet,jet],[W]],[[jet],[jet,jet],[W]]]  (prompt,prompt)
 13.0          1.047E+02    #        [[[b,t],[W]],[[jet,jet],[W]]]  (prompt,prompt)
 13.0          8.754E+01    #            [[[jet]],[[jet,jet],[W]]]  (prompt,prompt)
 13.0          8.654E+01    # [[[jet,jet],[W]],[[jet,jet],[higgs]]]  (prompt,prompt)
 13.0          7.520E+01    #            [[[jet],[W]],[[b,t],[W]]]  (prompt,prompt)
 13.0          7.333E+01    #  [[[jet,jet],[W]],[[jet],[b,t],[W]]]  (prompt,prompt)
 13.0          7.333E+01    #  [[[b,t],[W]],[[jet],[jet,jet],[W]]]  (prompt,prompt)
 13.0          6.576E+01    #  [[[jet],[W]],[[jet],[jet,jet],[W]]]  (prompt,prompt)
 13.0          6.214E+01    #    [[[jet],[W]],[[jet,jet],[higgs]]]  (prompt,prompt)
================================================================================
