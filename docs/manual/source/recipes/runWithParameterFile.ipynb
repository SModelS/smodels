# %% [markdown]
# # How To: Run SModelS using a parameter file

# %%
# Set up the path to SModelS installation folder
import sys; sys.path.append("."); import smodels_paths

# %%
# Import those parts of smodels that are needed for this exercise
from smodels.installation import installDirectory, version
from smodels.tools import modelTester
from smodels.tools import crashReport
from smodels.tools import smodelsLogging
from smodels.tools import runtime
from smodels import particlesLoader
from importlib import reload

# %%
#Define the SLHA file name
filename="inputFiles/slha/gluino_squarks.slha"
#Define the parameter file
parameterFile="./parameters.ini"

# %%
#Read and check parameter file, exit parameterFile does not exist
parser = modelTester.getParameters(parameterFile)
#Display defined options:
for section in parser.sections():
    print(section)
    for option in parser.options(section):
        print('  ',option,'=',parser.get(section,option))
# Out:
# options
#    checkinput = True
#    doinvisible = True
#    docompress = True
#    computestatistics = True
#    testcoverage = True
#    combinesrs = False
# particles
#    model = share.models.mssm
#    promptwidth = 1e-11
#    stablewidth = 1e-25
# parameters
#    sigmacut = 0.01
#    minmassgap = 5.
#    maxcond = 0.2
#    ncpus = 1
# database
#    path = official
#    analyses = all
#    txnames = all
#    dataselector = all
# printer
#    outputtype = python,summary
# stdout-printer
#    printdatabase = False
#    addanainfo = False
#    printdecomp = False
#    addelementinfo = False
#    printextendedresults = False
#    addcoverageid = False
# summary-printer
#    expandedsummary = True
# slha-printer
#    expandedoutput = True
# python-printer
#    addelementlist = False
#    addtxweights = False
# xml-printer
#    addelementlist = False
#    addtxweights = False

# %%
#Change option:
parser.set('printer','outputtype','summary')

# %%
#Determine particles module from ini file, if necessary """
if parser.has_option("particles","model"):
    runtime.modelFile = parser.get( "particles", "model" )
    reload(particlesLoader)

#Load the database defined in the parameters file, exit if not found """
database, databaseVersion = modelTester.loadDatabase(parser,db=None)
listOfExpRes = modelTester.loadDatabaseResults(parser, database)

# %%
#Set local dir as output folder:
outputDir = './'
#run SModelS with input file:
output = modelTester.testPoint(filename, outputDir, parser, databaseVersion,listOfExpRes)
# Out:
# WARNING in printer.setOutPutFile() in 663: Removing old output file ./gluino_squarks.slha.smodels

# %%
# As we're not exiting the program, let's make sure all output is flushed
[ x.flush() for x in output.values() ]
# Out:
# {'summary': 'Input status: 1\nDecomposition output status: 1 #decomposition was successful\n# Input File: inputFiles/slha/gluino_squarks.slha\n# checkinput = True\n# combinesrs = False\n# computestatistics = True\n# docompress = True\n# doinvisible = True\n# maxcond = 0.2\n# minmassgap = 5.\n# model = share.models.mssm\n# ncpus = 1\n# promptwidth = 1e-11\n# sigmacut = 0.01\n# stablewidth = 1e-25\n# testcoverage = True\n# Database version: 2.2.0\n================================================================================\n#Analysis  Sqrts  Cond_Violation  Theory_Value(fb)  Exp_limit(fb)  r  r_expected\n\n ATLAS-SUSY-2016-07  1.30E+01    0.0  9.794E+00  1.270E+00  7.712E+00  9.154E+00\n Signal Region:  5j_Meff_1600\n Txnames:  T1, T2, T5GQ, T5WW, T5ZZ, T6WW, TGQ\n Likelihoods: L, L_max, L_SM =  2.536E-60,  9.778E-04,  9.077E-04\n--------------------------------------------------------------------------------\n ATLAS-SUSY-2018-10  1.30E+01    0.0  2.468E-01  5.820E-02  4.240E+00  4.240E+00\n Signal Region:  4j0blowx_3\n Txnames:  T6WW\n Likelihoods: L, L_max, L_SM =  1.868E-10,  4.143E-02,  4.143E-02\n--------------------------------------------------------------------------------\n ATLAS-SUSY-2018-22  1.30E+01    0.0  1.169E+01  5.006E+00  2.335E+00  N/A\n Signal Region:  (UL)\n Txnames:  T2\n--------------------------------------------------------------------------------\n     CMS-SUS-19-006  1.30E+01    0.0  1.169E+01  5.138E+00  2.274E+00  1.898E+00\n Signal Region:  (UL)\n Txnames:  T2\n--------------------------------------------------------------------------------\n     CMS-SUS-16-033  1.30E+01    0.0  6.311E+00  4.100E+00  1.539E+00  1.697E+00\n Signal Region:  SR3_Njet5_Nb0_HT500_MHT_500\n Txnames:  T1, T1bbbb, T1tttt, T2, T2tt, T5GQ, TGQ\n Likelihoods: L, L_max, L_SM =  3.731E-07,  9.756E-05,  9.555E-05\n--------------------------------------------------------------------------------\n     CMS-SUS-16-036  1.30E+01    0.0  1.169E+01  7.689E+00  1.520E+00  1.373E+00\n Signal Region:  (UL)\n Txnames:  T2\n--------------------------------------------------------------------------------\n ATLAS-SUSY-2018-22  1.30E+01    0.0  2.311E+00  1.550E+00  1.491E+00  1.116E+00\n Signal Region:  SR2j_1600\n Txnames:  T2\n Likelihoods: L, L_max, L_SM =  3.970E-07,  2.261E-05,  2.261E-05\n--------------------------------------------------------------------------------\n     CMS-SUS-16-033  1.30E+01    0.0  1.169E+01  8.658E+00  1.350E+00  1.198E+00\n Signal Region:  (UL)\n Txnames:  T2\n--------------------------------------------------------------------------------\n     CMS-SUS-13-012  8.00E+00    0.0  3.447E-01  2.930E-01  1.177E+00  6.134E-01\n Signal Region:  6NJet8_1500HTinf_300MHTinf\n Txnames:  T1, T1bbbb, T1tttt, T2, T2tt, T5WW, T5ZZ, T6WW, T6bbWW, TChiWW, TChiZZ\n Likelihoods: L, L_max, L_SM =  6.148E-04,  1.210E-02,  1.210E-02\n--------------------------------------------------------------------------------\n     CMS-SUS-16-033  1.30E+01    0.0  7.530E+00  6.778E+00  1.111E+00  5.420E-01\n Signal Region:  (UL)\n Txnames:  T1\n--------------------------------------------------------------------------------\n ATLAS-SUSY-2016-07  1.30E+01    0.0  4.911E+01  5.375E+01  9.137E-01  N/A\n Signal Region:  (UL)\n Txnames:  T6WW\n--------------------------------------------------------------------------------\n CMS-SUS-19-006-agg  1.30E+01    0.0  2.565E-01  3.143E-01  8.162E-01  1.271E+00\n Signal Region:  AR17\n Txnames:  T1, T1bbbb, T1tttt, T2, T2tt, T6bbWW\n Likelihoods: L, L_max, L_SM =  7.458E-04,  1.607E-03,  7.542E-04\n--------------------------------------------------------------------------------\n     CMS-SUS-16-036  1.30E+01    0.0  7.530E+00  9.294E+00  8.101E-01  4.448E-01\n Signal Region:  (UL)\n Txnames:  T1\n--------------------------------------------------------------------------------\n ATLAS-SUSY-2016-07  1.30E+01    0.0  1.169E+01  1.632E+01  7.161E-01  N/A\n Signal Region:  (UL)\n Txnames:  T2\n-------------- ...

# %% [markdown]
# [Download output](./gluino_squarks.slha.smodels)

# %% [markdown]
# ### Display output:

# %%
# !cat gluino_squarks.slha.smodels
# Out:
# Input status: 1
# Decomposition output status: 1 #decomposition was successful
# # Input File: inputFiles/slha/gluino_squarks.slha
# # checkinput = True
# # combinesrs = False
# # computestatistics = True
# # docompress = True
# # doinvisible = True
# # maxcond = 0.2
# # minmassgap = 5.
# # model = share.models.mssm
# # ncpus = 1
# # promptwidth = 1e-11
# # sigmacut = 0.01
# # stablewidth = 1e-25
# # testcoverage = True
# # Database version: 2.2.0
# ================================================================================
# #Analysis  Sqrts  Cond_Violation  Theory_Value(fb)  Exp_limit(fb)  r  r_expected
#
#  ATLAS-SUSY-2016-07  1.30E+01    0.0  9.794E+00  1.270E+00  7.712E+00  9.154E+00
#  Signal Region:  5j_Meff_1600
#  Txnames:  T1, T2, T5GQ, T5WW, T5ZZ, T6WW, TGQ
#  Likelihoods: L, L_max, L_SM =  2.536E-60,  9.778E-04,  9.077E-04
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-10  1.30E+01    0.0  2.468E-01  5.820E-02  4.240E+00  4.240E+00
#  Signal Region:  4j0blowx_3
#  Txnames:  T6WW
#  Likelihoods: L, L_max, L_SM =  1.868E-10,  4.143E-02,  4.143E-02
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-22  1.30E+01    0.0  1.169E+01  5.006E+00  2.335E+00  N/A
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#      CMS-SUS-19-006  1.30E+01    0.0  1.169E+01  5.138E+00  2.274E+00  1.898E+00
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#      CMS-SUS-16-033  1.30E+01    0.0  6.311E+00  4.100E+00  1.539E+00  1.697E+00
#  Signal Region:  SR3_Njet5_Nb0_HT500_MHT_500
#  Txnames:  T1, T1bbbb, T1tttt, T2, T2tt, T5GQ, TGQ
#  Likelihoods: L, L_max, L_SM =  3.731E-07,  9.756E-05,  9.555E-05
# --------------------------------------------------------------------------------
#      CMS-SUS-16-036  1.30E+01    0.0  1.169E+01  7.689E+00  1.520E+00  1.373E+00
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-22  1.30E+01    0.0  2.311E+00  1.550E+00  1.491E+00  1.116E+00
#  Signal Region:  SR2j_1600
#  Txnames:  T2
#  Likelihoods: L, L_max, L_SM =  3.970E-07,  2.261E-05,  2.261E-05
# --------------------------------------------------------------------------------
#      CMS-SUS-16-033  1.30E+01    0.0  1.169E+01  8.658E+00  1.350E+00  1.198E+00
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#      CMS-SUS-13-012  8.00E+00    0.0  3.447E-01  2.930E-01  1.177E+00  6.134E-01
#  Signal Region:  6NJet8_1500HTinf_300MHTinf
#  Txnames:  T1, T1bbbb, T1tttt, T2, T2tt, T5WW, T5ZZ, T6WW, T6bbWW, TChiWW, TChiZZ
#  Likelihoods: L, L_max, L_SM =  6.148E-04,  1.210E-02,  1.210E-02
# --------------------------------------------------------------------------------
#      CMS-SUS-16-033  1.30E+01    0.0  7.530E+00  6.778E+00  1.111E+00  5.420E-01
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-07  1.30E+01    0.0  4.911E+01  5.375E+01  9.137E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T6WW
# --------------------------------------------------------------------------------
#  CMS-SUS-19-006-agg  1.30E+01    0.0  2.565E-01  3.143E-01  8.162E-01  1.271E+00
#  Signal Region:  AR17
#  Txnames:  T1, T1bbbb, T1tttt, T2, T2tt, T6bbWW
#  Likelihoods: L, L_max, L_SM =  7.458E-04,  1.607E-03,  7.542E-04
# --------------------------------------------------------------------------------
#      CMS-SUS-16-036  1.30E+01    0.0  7.530E+00  9.294E+00  8.101E-01  4.448E-01
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-07  1.30E+01    0.0  1.169E+01  1.632E+01  7.161E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#      CMS-SUS-19-006  1.30E+01    0.0  7.530E+00  1.273E+01  5.917E-01  6.798E-01
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-20  8.00E+00    0.0  6.736E+00  1.157E+01  5.824E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T6WW
# --------------------------------------------------------------------------------
#      CMS-SUS-13-019  8.00E+00    0.0  2.120E+00  3.762E+00  5.637E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-02  8.00E+00    0.0  7.911E-01  1.818E+00  4.351E-01  5.231E-01
#  Signal Region:  SR2jt
#  Txnames:  T1, T2
#  Likelihoods: L, L_max, L_SM =  1.202E-03,  1.379E-03,  1.200E-03
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-02  8.00E+00    0.0  6.736E+00  1.718E+01  3.920E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T6WW
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-02  8.00E+00    0.0  2.120E+00  6.096E+00  3.478E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-04  8.00E+00    0.0  1.527E-01  5.060E-01  3.018E-01  3.291E-01
#  Signal Region:  GtGrid_SR_7ej80_0bjet
#  Txnames:  T1bbbb, T1tttt, T2tt, T5WW, T5ZZ, T6bbWW
#  Likelihoods: L, L_max, L_SM =  1.833E-02,  2.074E-02,  2.012E-02
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-02  8.00E+00    0.0  9.069E+00  3.233E+01  2.805E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T5WW
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2015-06  1.30E+01    0.0  4.256E+00  1.570E+01  2.711E-01  2.711E-01
#  Signal Region:  SR2jm
#  Txnames:  T1, T2
#  Likelihoods: L, L_max, L_SM =  4.736E-04,  5.481E-04,  5.481E-04
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-32  1.30E+01    0.0  1.446E+02  5.550E+02  2.605E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWW
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-07  1.30E+01    0.0  7.530E+00  3.026E+01  2.489E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-23  1.30E+01    0.0  2.071E+02  9.808E+02  2.112E-01  2.551E-01
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2019-09  1.30E+01    0.0  3.990E+01  1.946E+02  2.050E-01  1.642E-01
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-13-012  8.00E+00    0.0  2.120E+00  1.077E+01  1.969E-01  3.477E-01
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2019-08  1.30E+01    0.0  2.071E+02  1.148E+03  1.804E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2019-08  1.30E+01    0.0  9.065E-03  5.310E-02  1.707E-01  1.707E-01
#  Signal Region:  SR_LM_High_MCT
#  Txnames:  TChiWH
#  Likelihoods: L, L_max, L_SM =  3.511E-02,  3.944E-02,  3.944E-02
# --------------------------------------------------------------------------------
#      CMS-SUS-17-004  1.30E+01    0.0  2.071E+02  1.572E+03  1.317E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#      CMS-SUS-12-028  8.00E+00    0.0  2.120E+00  1.645E+01  1.289E-01  2.217E-01
#  Signal Region:  (UL)
#  Txnames:  T2
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-09  8.00E+00    0.0  9.069E+00  7.070E+01  1.283E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T5WW
# --------------------------------------------------------------------------------
#      CMS-SUS-18-007  1.30E+01    0.0  2.071E+02  1.627E+03  1.273E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-10  1.30E+01    0.0  2.459E+01  1.966E+02  1.251E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  T6WW
# --------------------------------------------------------------------------------
#      CMS-SUS-17-004  1.30E+01    0.0  3.990E+01  3.678E+02  1.085E-01  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-07  1.30E+01    0.0  1.032E+02  1.038E+03  9.939E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  T5WW
# --------------------------------------------------------------------------------
#      CMS-SUS-16-039  1.30E+01    0.0  2.071E+02  2.115E+03  9.793E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-31  1.30E+01    0.0  2.871E-01  3.185E+00  9.015E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  T6bbHH
# --------------------------------------------------------------------------------
#      CMS-SUS-16-039  1.30E+01    0.0  3.990E+01  4.680E+02  8.526E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-16-045  1.30E+01    0.0  2.071E+02  2.437E+03  8.498E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#      CMS-SUS-13-006  8.00E+00    0.0  9.588E+01  1.136E+03  8.440E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-11  8.00E+00    0.0  4.477E-02  5.310E-01  8.431E-02  1.022E-01
#  Signal Region:  WWc-DF
#  Txnames:  TChiWW
#  Likelihoods: L, L_max, L_SM =  2.082E-02,  2.165E-02,  1.893E-02
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-24  1.30E+01    0.0  7.639E-03  1.000E-01  7.639E-02  6.160E-02
#  Signal Region:  WZ-0Jb
#  Txnames:  TChiWZ
#  Likelihoods: L, L_max, L_SM =  1.278E-01,  1.519E-01,  1.519E-01
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2019-09  1.30E+01    0.0  7.191E-03  9.530E-02  7.546E-02  9.824E-02
#  Signal Region:  SRWZ_14
#  Txnames:  TChiWZ
#  Likelihoods: L, L_max, L_SM =  2.346E-02,  2.597E-02,  2.053E-02
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2017-03  1.30E+01    0.0  6.657E-03  9.000E-02  7.396E-02  5.325E-02
#  Signal Region:  SR2l_Int
#  Txnames:  TChiWZ
#  Likelihoods: L, L_max, L_SM =  9.587E-02,  1.087E-01,  1.087E-01
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-06  1.30E+01    0.0  1.256E-02  1.720E-01  7.304E-02  9.306E-02
#  Signal Region:  SR_low
#  Txnames:  TChiWZ
#  Likelihoods: L, L_max, L_SM =  4.145E-03,  4.450E-03,  3.757E-03
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-31  1.30E+01    0.0  2.050E-03  2.990E-02  6.857E-02  4.012E-02
#  Signal Region:  SRA_M
#  Txnames:  T6bbHH
#  Likelihoods: L, L_max, L_SM =  4.835E-02,  5.511E-02,  5.511E-02
# --------------------------------------------------------------------------------
#      CMS-SUS-13-019  8.00E+00    0.0  6.619E-01  9.690E+00  6.831E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-24  1.30E+01    0.0  3.990E+01  5.848E+02  6.823E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-02  8.00E+00    0.0  6.619E-01  1.082E+01  6.118E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#      CMS-SUS-13-012  8.00E+00    0.0  6.619E-01  1.113E+01  5.949E-02  8.261E-02
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-09  8.00E+00    0.0  5.004E-02  8.670E-01  5.771E-02  1.303E-01
#  Signal Region:  SR0B
#  Txnames:  T1tttt, T5WW
#  Likelihoods: L, L_max, L_SM =  5.078E-03,  1.838E-02,  3.141E-03
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-12  8.00E+00    0.0  1.847E+01  3.306E+02  5.586E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#  CMS-SUS-16-039-agg  1.30E+01    0.0  5.091E-02  9.549E-01  5.332E-02  5.463E-02
#  Signal Region:  AR1
#  Txnames:  TChiWZ
#  Likelihoods: L, L_max, L_SM =  5.299E-04,  5.302E-04,  5.298E-04
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-06  1.30E+01    0.0  3.990E+01  8.254E+02  4.834E-02  7.675E-02
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-22  1.30E+01    0.0  2.459E+01  5.174E+02  4.752E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  T6WW
# --------------------------------------------------------------------------------
#      CMS-SUS-13-006  8.00E+00    0.0  1.847E+01  4.656E+02  3.967E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-20-001  1.30E+01    0.0  3.990E+01  1.142E+03  3.494E-02  4.601E-02
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-16-034  1.30E+01    0.0  3.990E+01  1.572E+03  2.539E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-12-028  8.00E+00    0.0  6.619E-01  3.163E+01  2.093E-02  3.356E-02
#  Signal Region:  (UL)
#  Txnames:  T1
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-11  8.00E+00    0.0  1.847E+01  9.250E+02  1.997E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-16-043  1.30E+01    0.0  2.071E+02  1.271E+04  1.629E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWH
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-26  1.30E+01    0.0  2.488E-01  1.628E+01  1.528E-02  N/A
#  Signal Region:  (UL)
#  Txnames:  T2cc
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-40  1.30E+01    0.0  6.687E-04  4.930E-02  1.356E-02  1.356E-02
#  Signal Region:  SingleBin
#  Txnames:  T6bbHH
#  Likelihoods: L, L_max, L_SM =  5.191E-02,  5.196E-02,  5.179E-02
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2017-03  1.30E+01    0.0  3.990E+01  4.178E+03  9.551E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  TChiWZ
# --------------------------------------------------------------------------------
#      CMS-SUS-19-006  1.30E+01    0.0  1.536E-02  1.657E+00  9.270E-03  9.270E-03
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#      CMS-SUS-19-006  1.30E+01    0.0  3.496E-02  4.214E+00  8.296E-03  8.926E-03
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-037  1.30E+01    0.0  3.496E-02  4.442E+00  7.870E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-20-002  1.30E+01    0.0  1.004E-02  1.482E+00  6.774E-03  5.511E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-050  1.30E+01    0.0  3.496E-02  5.508E+00  6.348E-03  6.533E-03
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-033  1.30E+01    0.0  3.496E-02  6.842E+00  5.110E-03  3.995E-03
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-036  1.30E+01    0.0  1.536E-02  3.360E+00  4.572E-03  3.087E-03
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#      CMS-SUS-16-042  1.30E+01    0.0  3.496E-02  7.846E+00  4.456E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-19-009  1.30E+01    0.0  1.004E-02  2.674E+00  3.755E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-033  1.30E+01    0.0  1.536E-02  4.926E+00  3.119E-03  3.169E-03
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#      CMS-SUS-19-008  1.30E+01    0.0  3.496E-02  1.210E+01  2.890E-03  4.198E-03
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-19-006  1.30E+01    0.0  1.004E-02  3.655E+00  2.747E-03  1.960E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  CMS-SUS-16-050-agg  1.30E+01    0.0  1.399E-04  5.351E-02  2.615E-03  2.615E-03
#  Signal Region:  ar39
#  Txnames:  T1tttt, T2tt
#  Likelihoods: L, L_max, L_SM =  2.476E-01,  2.489E-01,  2.489E-01
# --------------------------------------------------------------------------------
#      CMS-SUS-16-036  1.30E+01    0.0  3.496E-02  1.457E+01  2.400E-03  2.646E-03
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-12  1.30E+01    0.0  1.004E-02  4.583E+00  2.191E-03  2.687E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-009  1.30E+01    0.0  3.496E-02  1.703E+01  2.053E-03  1.479E-03
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-051  1.30E+01    0.0  1.004E-02  5.010E+00  2.004E-03  1.284E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-036  1.30E+01    0.0  1.004E-02  5.135E+00  1.955E-03  1.245E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-12  1.30E+01    0.0  8.211E-05  4.400E-02  1.866E-03  2.294E-03
#  Signal Region:  SRATT
#  Txnames:  T2tt
#  Likelihoods: L, L_max, L_SM =  1.435E-01,  1.559E-01,  1.431E-01
# --------------------------------------------------------------------------------
#      CMS-SUS-16-049  1.30E+01    0.0  1.004E-02  7.049E+00  1.424E-03  2.200E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-050  1.30E+01    0.0  1.004E-02  7.146E+00  1.405E-03  2.112E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-041  1.30E+01    0.0  3.496E-02  2.533E+01  1.381E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-035  1.30E+01    0.0  3.496E-02  2.763E+01  1.265E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-15  1.30E+01    0.0  1.004E-02  8.581E+00  1.170E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-18  8.00E+00    0.0  1.917E-04  1.700E-01  1.128E-03  6.390E-04
#  Signal Region:  SR-1l-6j-B
#  Txnames:  T1tttt
#  Likelihoods: L, L_max, L_SM =  4.952E-04,  4.971E-04,  4.971E-04
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-08  1.30E+01    0.0  1.004E-02  1.000E+01  1.004E-03  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-16  1.30E+01    0.0  1.004E-02  1.015E+01  9.896E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-033  1.30E+01    0.0  1.004E-02  1.071E+01  9.374E-04  1.160E-03
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-14  1.30E+01    0.0  3.496E-02  3.804E+01  9.190E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  CMS-PAS-SUS-13-023  8.00E+00    0.0  2.597E-03  3.014E+00  8.615E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-14-010  8.00E+00    0.0  3.074E-03  3.687E+00  8.337E-04  6.416E-04
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-18  8.00E+00    0.0  3.074E-03  3.810E+00  8.067E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-19-011  1.30E+01    0.0  1.004E-02  1.254E+01  8.007E-04  8.120E-04
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-004  8.00E+00    0.0  2.597E-03  3.305E+00  7.859E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-007  8.00E+00    0.0  3.074E-03  4.112E+00  7.475E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2018-08  1.30E+01    0.0  2.373E-05  3.720E-02  6.380E-04  6.380E-04
#  Signal Region:  SRDF220
#  Txnames:  T2tt
#  Likelihoods: L, L_max, L_SM =  1.332E-01,  1.332E-01,  1.332E-01
# --------------------------------------------------------------------------------
#      CMS-SUS-13-019  8.00E+00    0.0  1.350E-03  2.477E+00  5.453E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-16  1.30E+01    0.0  4.166E-04  8.610E-01  4.839E-04  7.891E-04
#  Signal Region:  tN_med
#  Txnames:  T2tt
#  Likelihoods: L, L_max, L_SM =  1.188E-03,  3.405E-03,  1.185E-03
# --------------------------------------------------------------------------------
#      CMS-SUS-17-001  1.30E+01    0.0  1.004E-02  2.959E+01  3.394E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-019  8.00E+00    0.0  3.074E-03  9.129E+00  3.367E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-16-009  1.30E+01    0.0  1.004E-02  3.059E+01  3.282E-04  3.843E-04
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-18  8.00E+00    0.0  1.350E-03  4.117E+00  3.280E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#      CMS-SUS-13-004  8.00E+00    0.0  1.350E-03  4.338E+00  3.113E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#      CMS-SUS-12-024  8.00E+00    0.0  1.184E-04  3.850E-01  3.076E-04  4.526E-04
#  Signal Region:  MET4_HT4_nb3
#  Txnames:  T1bbbb, T1tttt
#  Likelihoods: L, L_max, L_SM =  4.657E-02,  7.085E-02,  4.651E-02
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-04  8.00E+00    0.0  3.074E-03  1.091E+01  2.816E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-019  8.00E+00    0.0  2.597E-03  9.359E+00  2.775E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2015-02  1.30E+01    0.0  3.249E-04  1.260E+00  2.579E-04  2.579E-04
#  Signal Region:  SR2
#  Txnames:  T2tt
#  Likelihoods: L, L_max, L_SM =  5.501E-01,  5.502E-01,  5.502E-01
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2013-09  8.00E+00    0.0  3.074E-03  1.356E+01  2.267E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-002  8.00E+00    0.0  3.074E-03  1.635E+01  1.879E-04  1.082E-04
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  ATLAS-SUSY-2016-17  1.30E+01    0.0  1.004E-02  5.358E+01  1.874E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-012  8.00E+00    0.0  3.074E-03  1.657E+01  1.855E-04  2.749E-04
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-004  8.00E+00    0.0  3.074E-03  1.680E+01  1.829E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-013  8.00E+00    0.0  3.074E-03  1.763E+01  1.743E-04  1.622E-04
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-13-013  8.00E+00    0.0  4.168E-05  2.575E-01  1.618E-04  1.612E-04
#  Signal Region:  SR28_HighPt
#  Txnames:  T1tttt
#  Likelihoods: L, L_max, L_SM =  1.098E-01,  1.098E-01,  1.098E-01
# --------------------------------------------------------------------------------
#      CMS-SUS-12-028  8.00E+00    0.0  1.350E-03  9.521E+00  1.418E-04  1.895E-04
#  Signal Region:  (UL)
#  Txnames:  T1bbbb
# --------------------------------------------------------------------------------
#  CMS-PAS-SUS-13-016  8.00E+00    0.0  2.906E-05  2.110E-01  1.377E-04  1.371E-04
#  Signal Region:  sr0
#  Txnames:  T1tttt
#  Likelihoods: L, L_max, L_SM =  1.387E-01,  1.387E-01,  1.387E-01
# --------------------------------------------------------------------------------
#      CMS-SUS-13-007  8.00E+00    0.0  2.074E-05  1.550E-01  1.338E-04  1.340E-04
#  Signal Region:  mu350Nb3
#  Txnames:  T1tttt
#  Likelihoods: L, L_max, L_SM =  3.773E-01,  3.775E-01,  3.775E-01
# --------------------------------------------------------------------------------
#      CMS-SUS-17-010  1.30E+01    0.0  1.004E-02  8.053E+01  1.247E-04  1.282E-04
#  Signal Region:  (UL)
#  Txnames:  T2tt
# --------------------------------------------------------------------------------
#      CMS-SUS-12-024  8.00E+00    0.0  3.074E-03  2.604E+01  1.180E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#  CMS-PAS-SUS-13-016  8.00E+00    0.0  3.074E-03  3.036E+01  1.012E-04  N/A
#  Signal Region:  (UL)
#  Txnames:  T1tttt
# --------------------------------------------------------------------------------
#      CMS-SUS-12-028  8.00E+00    0.0  3.074E-03  3.634E+01  8.458E-05  1.206E-04
#  Signal Region:  (UL)
#  Txnames:  T1tttt
#
#
# ================================================================================
# The highest r value is = 7.71217 from ATLAS-SUSY-2016-07 (r_expected=9.15369)
# CMS analysis with highest available r_expected: CMS-SUS-19-006, r_expected=1.89768, r_obs=2.27446
# ATLAS analysis with highest available r_expected: ATLAS-SUSY-2016-07, r_expected=9.15369, r_obs=7.71217
#
# Total cross-section for missing topologies (fb):  2.821E+03
# Total cross-section for missing topologies with displaced decays (fb):  0.000E+00
# Total cross-section for missing topologies with prompt decays (fb):  2.838E+03
# Total cross-section for topologies outside the grid (fb):  2.118E+02
#
# #Full information on unconstrained cross sections
# ================================================================================
# missing topologies with the highest cross sections (up to 10):
# Sqrts (TeV)   Weight (fb)                  Element description
#  13.0          1.482E+02    #              [[[jet],[W]],[[jet,jet],[W]]]  (MET,MET)
#  13.0          1.445E+02    #    [[[jet,jet],[W]],[[jet],[jet,jet],[W]]]  (MET,MET)
#  13.0          1.047E+02    #              [[[jet,jet],[W]],[[b,t],[W]]]  (MET,MET)
#  13.0          8.754E+01    #                  [[[jet]],[[jet,jet],[W]]]  (MET,MET)
#  13.0          7.520E+01    #                  [[[jet],[W]],[[b,t],[W]]]  (MET,MET)
#  13.0          7.333E+01    #        [[[jet,jet],[W]],[[jet],[b,t],[W]]]  (MET,MET)
#  13.0          7.333E+01    #        [[[b,t],[W]],[[jet],[jet,jet],[W]]]  (MET,MET)
#  13.0          6.576E+01    #        [[[jet],[W]],[[jet],[jet,jet],[W]]]  (MET,MET)
#  13.0          6.214E+01    #          [[[jet],[W]],[[jet,jet],[higgs]]]  (MET,MET)
#  13.0          6.198E+01    #          [[[jet],[higgs]],[[jet,jet],[W]]]  (MET,MET)
# ================================================================================
# No missing topologies with displaced decays found
# ================================================================================
# missing topologies with prompt decays with the highest cross sections (up to 10):
# Sqrts (TeV)   Weight (fb)                  Element description
#  13.0          1.482E+02    #              [[[jet],[W]],[[jet,jet],[W]]]  (MET,MET)
#  13.0          1.445E+02    #    [[[jet,jet],[W]],[[jet],[jet,jet],[W]]]  (MET,MET)
#  13.0          1.047E+02    #              [[[jet,jet],[W]],[[b,t],[W]]]  (MET,MET)
#  13.0          8.754E+01    #                  [[[jet]],[[jet,jet],[W]]]  (MET,MET)
#  13.0          7.520E+01    #                  [[[jet],[W]],[[b,t],[W]]]  (MET,MET)
#  13.0          7.333E+01    #        [[[jet,jet],[W]],[[jet],[b,t],[W]]]  (MET,MET)
#  13.0          7.333E+01    #        [[[b,t],[W]],[[jet],[jet,jet],[W]]]  (MET,MET)
#  13.0          6.576E+01    #        [[[jet],[W]],[[jet],[jet,jet],[W]]]  (MET,MET)
#  13.0          6.214E+01    #          [[[jet],[W]],[[jet,jet],[higgs]]]  (MET,MET)
#  13.0          6.198E+01    #          [[[jet],[higgs]],[[jet,jet],[W]]]  (MET,MET)
# ================================================================================
# topologies outside the grid with the highest cross sections (up to 10):
# Sqrts (TeV)   Weight (fb)                  Element description
#  13.0          8.654E+01    #      [[[jet,jet],[higgs]],[[jet,jet],[W]]]  (MET,MET)
#  13.0          4.111E+01    #              [[[jet],[higgs]],[[jet],[W]]]  (MET,MET)
#  13.0          1.815E+01    #  [[[jet,jet],[higgs]],[[jet,jet],[higgs]]]  (MET,MET)
#  13.0          1.667E+01    #          [[[jet,jet],[W]],[[jet,jet],[Z]]]  (MET,MET)
#  13.0          8.603E+00    #          [[[jet],[higgs]],[[jet],[higgs]]]  (MET,MET)
#  13.0          7.826E+00    #                  [[[jet],[W]],[[jet],[Z]]]  (MET,MET)
#  13.0          6.992E+00    #      [[[jet,jet],[higgs]],[[jet,jet],[Z]]]  (MET,MET)
#  13.0          4.381E+00    #                        [[[W]],[[jet,jet]]]  (MET,MET)
#  13.0          3.444E+00    #                               [[],[[jet]]]  (MET,MET)
#  13.0          3.245E+00    #              [[[jet],[higgs]],[[jet],[Z]]]  (MET,MET)
# ================================================================================
