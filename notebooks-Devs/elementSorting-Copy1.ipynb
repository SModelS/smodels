# %%
import sys
sys.path.append('../')
import networkx as nx
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout
from smodels.theory.element import Element
from smodels.theory.tree import Tree, compareNodes
from smodels.particlesLoader import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.theory.model import Model
from smodels.theory.auxiliaryFunctions import index_bisect
from collections import OrderedDict
from smodels.tools.physicsUnits import fb, GeV

# %%
slhafile="../inputFiles/slha/lightEWinos.slha"
model = Model(BSMList,SMList)
model.updateParticles(inputFile=slhafile,promptWidth = 1e-12*GeV)

# %%
elA  = Element("(PV > gluino(1),gluino(2)), (gluino(1) > N3(3),g), (gluino(2) > b,b,N1), (N3(3) > C1+(4),W-), (C1+(4) > q,q,N1)",
              model=model)
elB = Element("(PV > gluino(1),gluino(2)), (gluino(1) > N3(3),g), (gluino(2) > b,b,N1), (N3(3) > C1+(4),W-), (C1+(4) > q,q,N1)",
              model=model)

# %%
elA.drawTree()

# %%
newEl = elA.compareTo(elB)[1]
newEl.drawTree()

# %%
newEl.tree.getTreeRoot()
# Out:
# PV

# %%
print(elB.tree.nodes)
print(elB.tree.nodes)
print(newEl.tree.nodes)
# Out:
# [PV, gluino, N3, gluino, C1+, g, W-, b, b, q, q, N1, N1]
# [PV, gluino, N3, gluino, C1+, g, W-, b, b, q, q, N1, N1]
# [PV, gluino, N3, gluino, C1+, g, W-, b, b, q, q, N1, N1]

# %%
elA += newEl

# %%
elA.drawTree()

# %%
print(elB.tree.nodes)
print(elB.tree.nodes)
print(newEl.tree.nodes)
# Out:
# [PV, gluino, N3, gluino, C1+, g, W-, b, b, q, q, N1, N1]
# [PV, gluino, N3, gluino, C1+, g, W-, b, b, q, q, N1, N1]
# [PV, gluino, N3, gluino, C1+, g, W-, b, b, q, q, N1, N1]
