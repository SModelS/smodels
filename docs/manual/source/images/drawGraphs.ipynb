# %%
import sys
sys.path.append('../../../../')
from smodels.base.genericSMS import GenericSMS
from smodels.experiment.expSMS import ExpSMS
from smodels.experiment.defaultFinalStates import finalStates
from smodels.share.models.mssm import BSMList
from smodels.decomposition.theorySMS import TheorySMS
from smodels.share.models.SMparticles import SMList
from smodels.base.model import Model

# %%
sms = ExpSMS.from_string('(PV(0) > anyBSM(1)), (anyBSM(1) > jet(2),jet(3))',model=finalStates)

# %%
sms.draw()

# %%
sms.draw(particleColor='steelblue2',smColor='lightsalmon',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.4', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'})

# %%
sms.draw(usePVimage='./hardScatter.png')

# %%
sms = ExpSMS.from_string('(PV(0) > gluino(2),gluino(1)), (gluino(1) > jet,jet,MET(3)), (gluino(2) > C1+(4),jet,jet),(C1+(4) > W+,MET(5))',model=finalStates)
sms.draw()

# %%
sms = ExpSMS.from_string('(PV(0) > anyBSM(1))',model=finalStates)
sms.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'},
#          , filename='sms_example1a.png'
        )
sms = ExpSMS.from_string('(PV(0) > anyBSM(1)), (anyBSM(1) > jet(2),jet(3))',model=finalStates)
sms.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example1b.png'
        )

# %%
    smsB = ExpSMS.from_string('(PV(0) > anyBSM(1),anyBSM(2))',model=finalStates)
    smsB.draw(particleColor='steelblue2',smColor='lightpink2',
             graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
    #          usePVimage='./hardScatter.png',
             nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                    'shape' : 'circle','margin' : '0', 
                                    'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
             edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
    #          , filename='sms_example2a.png'
             )

smsB = ExpSMS.from_string('(PV(0) > anyBSM(1),anyBSM(2)), (anyBSM(1) > MET,jet), (anyBSM(2) > l,MET)',model=finalStates)
smsB.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#           , filename='sms_example2b.png'
         )

# %%
smsC = ExpSMS.from_string('(PV(0) > anyBSM(1),anyBSM(2))',model=finalStates)

smsC.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example3a.png'
         )

smsC = ExpSMS.from_string('(PV(0) > anyBSM(1),anyBSM(2)), (anyBSM(1) > anyBSM(3),jet,jet), (anyBSM(2) > l,MET), (anyBSM(3) > MET,e+)',model=finalStates)

smsC.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example3b.png'
         )

# %%
smsD = ExpSMS.from_string('(PV(0) > anyBSM(1),higgs(2))',model=finalStates)

smsD.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example4a.png'
         )

smsD = ExpSMS.from_string('(PV(0) > anyBSM(1),higgs(2)), (anyBSM(1) > MET,jet,jet)',model=finalStates)

smsD.draw(particleColor='steelblue2',smColor='lightpink2',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "LR"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example4b.png'
         )

# %% [markdown]
# ### Database graphs

# %%
sms = ExpSMS.from_string('(PV(0) > anyBSM(1)), (anyBSM(1) > jet(2),jet(3))',model=finalStates)
sms.draw(particleColor='steelblue4',smColor='lightpink3',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#         , filename='sms_example_db_1.png'
        )

# %%
smsB = ExpSMS.from_string('(PV(0) > anyBSM(1),anyBSM(2)), (anyBSM(1) > MET,jet), (anyBSM(2) > l,MET)',model=finalStates)
smsB.draw(particleColor='steelblue4',smColor='lightpink3',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example_db_2.png'
         )

# %%
smsC = ExpSMS.from_string('(PV(0) > anyBSM(1),anyBSM(2)), (anyBSM(1) > MET,jet,jet), (anyBSM(2) > l,MET)',model=finalStates)
smsC.draw(particleColor='steelblue4',smColor='lightpink3',
         graph_kwargs={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"},
#          usePVimage='./hardScatter.png',
         nodes_kwargs={'style' : 'filled', 'fontsize' : '5', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 
                                'label' : '', 'fixedsize' : 'true', 'width' : '0.4', 'height' : '0.4'},
         edges_kwargs={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
#          , filename='sms_example_db_3.png'
         )

# %% [markdown]
# ### Draw decomposition graphs

# %%
from smodels.decomposition.theorySMS import TheorySMS
from smodels.experiment.expSMS import ExpSMS
from smodels.share.models.mssm import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.base.model import Model

# %%
model = Model(BSMList,SMList)

# %%
smsA = "(PV > H0(1),H-(2)), (H0(1) > H+(3),H-(4)), (H+(3) > W+,higgs), (H-(4) > W-,higgs), (H-(2) > W-,higgs)"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
#     filename='sms_theory_example1.png'
)

# %%
smsA = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > u(6),N1(7))"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
#           filename='sms_theory_example2.png'
         )
smsA.draw(
#           filename='sms_canonName.png',
          labelAttr='canonName',maxLabelSize=80)
smsA.draw(
#           filename='sms_nodeIndices.png',
         labelAttr='node')

# %%
print(smsA)
# Out:
# (PV > gluino(1),su_L(2)), (gluino(1) > N1,q,q), (su_L(2) > q,N1)

# %%
sms = "(PV > H+(1)), (H+(1) > W+,H0)"
# Hack to create a theory element from a string:
sms = ExpSMS.from_string(sms, model=model)
sms.draw(
#         filename='sms_canon1a.png'
        )

sms = "(PV > H+(1)), (H+(1) > W+,higgs)"
# Hack to create a theory element from a string:
sms = ExpSMS.from_string(sms, model=model)
sms.draw(
        # filename='sms_example.png'
        )

# %%
print(sms.canonName)
# Out:
# 11101000

# %%
sms = ExpSMS.from_string('(PV(0) > anyBSM(1), anyBSM(2)), (anyBSM(1) > e+(3),MET(4)), (anyBSM(2) > e-(5),MET(6))',model=finalStates)
sms.draw(
#         filename='tslepslep1.png'
        )
print(sms.treeToString(removeIndicesFrom=None))
sms = ExpSMS.from_string('(PV(0) > anyBSM(1), anyBSM(2)), (anyBSM(1) > mu+(3),MET(4)), (anyBSM(2) > mu-(5),MET(6))',model=finalStates)
sms.draw(
#         filename='tslepslep2.png'
        )
print(sms.treeToString(removeIndicesFrom=None))
# Out:
# (PV > anyBSM(1),anyBSM(2)), (anyBSM(1) > e+(3),MET(4)), (anyBSM(2) > e-(5),MET(6))
# (PV > anyBSM(1),anyBSM(2)), (anyBSM(1) > mu+(3),MET(4)), (anyBSM(2) > mu-(5),MET(6))

# %% [markdown]
# ### Draw graphs for decomposition

# %%
# Production:
sms = smsA = "(PV > gluino(1),su_L(2))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None
#         , filename='sms_decomp1.png'
        )

# Decays:
nodes_kwargs={'style' : 'filled', 'fontsize' : '3', 
                       'fixedsize' : 'true',
                       'width' : '.3',
                       'color' : 'black','shape' : 'circle','margin' : '0'}

sms = "(PV > gluino(1)), (gluino(1) > N1(3),u(4),u~(5))"
sms = ExpSMS.from_string(sms, model=model)
sms.remove_node(0)
sms.draw(labelAttr=None,pvColor='steelblue2',nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp1a.png'
        )

sms = "(PV > gluino(1)), (gluino(1) > N1(3),u(4))"
sms = ExpSMS.from_string(sms, model=model)
sms.remove_node(0)
sms.draw(labelAttr=None,pvColor='steelblue2',nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp1b.png'
        )

sms = "(PV > gluino(1)), (gluino(1) > u(3),u(4))"

sms = ExpSMS.from_string(sms, model=model)
sms.remove_node(0)
sms.draw(labelAttr=None,pvColor='steelblue2',
         nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp1c.png'
        )

sms = "(PV > gluino(1)), (gluino(1) > N1(3),N2(4))"
sms = ExpSMS.from_string(sms, model=model)
sms.remove_node(0)
sms.draw(labelAttr=None,pvColor='steelblue2',
         nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp1d.png'
        )


sms = "(PV > gluino(1)), (gluino(1) > N1(3),N2(4))"
sms = ExpSMS.from_string(sms, model=model)
sms.remove_node(0)
sms.draw(labelAttr=None,pvColor='steelblue2',
         nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp1d.png'
        )

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp2a.png'
        )


sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > u(6),u(7))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp2b.png'
        )


sms = "(PV > gluino(1),su_L(2)), (gluino(1) > u(4),u~(5)), (su_L(2) > N1(6),u(7))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp2c.png'
        )

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None
#         , filename='sms_decomp3a.png'
        )

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N1(3) > N2(8), u(9)), (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp3b.png'
        )

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N1(3) > u(8), u(9)), (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_decomp3c.png'
        )

# %% [markdown]
# ### Mass Compression

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N1(3) >  N2(8), u(9)), (N2(8) > N1(12), u(13), u(14)) , (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_massCompA.png'
        )


sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N2(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N2(3) > N1(12), u(13), u(14)) , (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_massCompB.png'
        )

# %% [markdown]
# ### Invisible Compression

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N1(3) >  nu(8),nu(9)), (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_invCompA.png'
        )


sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
sms.draw(labelAttr=None, nodes_kwargs=nodes_kwargs
#         , filename='sms_invCompB.png'
        )

# %% [markdown]
# ### SMS Sorting

# %%
sms = "(PV > gluino(1),su_L(2)), (gluino(1) > N1(3),u(4),u~(5)), (su_L(2) > N1(6),u(7)), (N1(3) >  nu(8),nu(9)), (N1(6) > N2(10), N2(11))"
sms = ExpSMS.from_string(sms, model=model)
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}
sms.draw(labelAttr='canonName', nodes_kwargs=nodes_kwargs2
#         , filename='sms_sortA.png'
        )
sms.sort()
sms.draw(labelAttr='canonName', nodes_kwargs=nodes_kwargs2
#          , filename='sms_sortB.png'
        )

# %% [markdown]
# ### Inclusive SMS

# %%
from smodels.experiment.databaseObj import Database
db = Database('official')

# %%
# Look for inclusive results:
incSMS = []
for sms in db._allExpSMSDict:
    if str(sms.canonName) == '*':
        incSMS.append(sms)

# %%
print(len(incSMS))
# Out:
# 8

# %%
for sms in incSMS:
    sms.draw()

# %%
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}

sms = ExpSMS.from_string('(PV(0) > anyBSM(1), anyBSM(2)), (anyBSM(1) > l(3),MET(4)), (anyBSM(2) > jet(5),MET(6))',model=finalStates)
sms.draw(nodes_kwargs=nodes_kwargs2
#        , filename='sms_incA.png'
        )


incSMS[0].draw(nodes_kwargs=nodes_kwargs2
#         ,  filename='sms_incB.png'
        )

sms = ExpSMS.from_string('(PV(0) > C1(1), C1(2)), (C1(1) > anySM(3),MET(4)), (C1(2) > *anySM(5),MET(6))',model=finalStates)
sms.draw(nodes_kwargs=nodes_kwargs2
#        , filename='sms_incB2.png'
        )
sms = ExpSMS.from_string('(PV(0) > C1(1), C1(2)), (C1(1) > anySM(3),anySM(4),MET(5)), (C1(2) > *anySM(6),MET(7))',model=finalStates)
sms.draw(nodes_kwargs=nodes_kwargs2
#        , filename='sms_incB3.png'
        )

incSMS[4].draw(nodes_kwargs=nodes_kwargs2
#         ,  filename='sms_incC.png'
        )

sms = ExpSMS.from_string('(PV(0) > anyBSM(1), HSCP(2)), (anyBSM(1) > *anySM(3),MET(4))',model=finalStates)
sms.draw(nodes_kwargs=nodes_kwargs2
#        , filename='sms_incC2.png'
        )
sms = ExpSMS.from_string('(PV(0) > anyBSM(1), HSCP(2)), (anyBSM(1) > anyBSM(3),*anySM(4)), (anyBSM(3) > *anySM(5),MET(6))',model=finalStates)
sms.draw(nodes_kwargs=nodes_kwargs2
#        , filename='sms_incC3.png'
        )
sms = ExpSMS.from_string('(PV(0) > anyBSM(1), HSCP(2)), (anyBSM(1) > anyBSM(3),MET(4)), (anyBSM(3) > *anySM(5))',model=finalStates)
sms.draw(nodes_kwargs=nodes_kwargs2
#        , filename='sms_incC4.png'
        )

# %% [markdown]
# ### Theory Predictions

# %%
sms = "(PV > gluino(1),gluino(2)), (gluino(1) > N1(3),u(4),u~(5)), (gluino(2) > N1(6),d(7),d~(8))"
sms = ExpSMS.from_string(sms, model=model)
sms.sort()
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}
sms.draw(nodes_kwargs=nodes_kwargs2
#         ,  filename='sms_tpA.png'
        )

# %%
sms = "(PV > anyBSM(1),anyBSM(2)), (anyBSM(1) >jet(3), MET(4),jet(5)), (anyBSM(2) > jet(6),jet(7),MET(8))"
sms = ExpSMS.from_string(sms, model=finalStates)
graph_kwargs3={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"}
nodes_kwargs3={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}
edges_kwargs3={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
sms.draw(nodes_kwargs=nodes_kwargs3, graph_kwargs=graph_kwargs3,edges_kwargs=edges_kwargs3,
         particleColor='steelblue3',smColor='lightpink3'
#         , filename='sms_tpB.png'
        )
sms.draw(nodes_kwargs=nodes_kwargs3, graph_kwargs=graph_kwargs3,edges_kwargs=edges_kwargs3,
         particleColor='steelblue3',smColor='lightpink3',labelAttr=None
#         , filename='sms_tpB2.png'
        )
print(sms.canonName)
# Out:
# 111010100110101000

# %%
sms = "(PV > gluino(1),gluino(2)), (gluino(1) > N1(3),u~(4))"
sms = ExpSMS.from_string(sms, model=model)
sms.sort()
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}

sms.draw(nodes_kwargs=nodes_kwargs2,labelAttr='canonName'
#         ,  filename='sms_tpA2.png'
        )

# %%
sms = "(PV > anyBSM(1),anyBSM(2)), (anyBSM(1) >jet(3), MET(4))"
sms = ExpSMS.from_string(sms, model=finalStates)
graph_kwargs3={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"}
nodes_kwargs3={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}
edges_kwargs3={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
sms.draw(nodes_kwargs=nodes_kwargs3, graph_kwargs=graph_kwargs3,edges_kwargs=edges_kwargs3,
         particleColor='steelblue3',smColor='lightpink3',labelAttr='canonName'
#         , filename='sms_tpB2.png'
        )
print(sms.canonName)
# Out:
# 1101101000

# %%
sms = "(PV > gluino(1),N1(2)), (gluino(1) > N1(3),g(4))"
sms = ExpSMS.from_string(sms, model=model)
sms.sort()
nodes_kwargs2={'style' : 'filled', 'fontsize' : '15', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}

sms.draw(nodes_kwargs=nodes_kwargs2
        ,  filename='sms_tpC1.png'
        )

# %%
sms = "(PV > gluino(1),N1(2))"
sms = ExpSMS.from_string(sms, model=model)
sms.sort()
nodes_kwargs2={'style' : 'filled', 'fontsize' : '15', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}

sms.draw(nodes_kwargs=nodes_kwargs2
#         ,  filename='sms_tpC4.png'
        )

# %%
sms = "(PV > anyBSM(1),MET(2)), (anyBSM(1) >jet(3), MET(4))"
sms = ExpSMS.from_string(sms, model=finalStates)
graph_kwargs3={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"}
nodes_kwargs3={'style' : 'filled', 'fontsize' : '15', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}
edges_kwargs3={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
sms.draw(nodes_kwargs=nodes_kwargs3, graph_kwargs=graph_kwargs3,edges_kwargs=edges_kwargs3,
         particleColor='steelblue3',smColor='lightpink3'
#         , filename='sms_tpC2.png'
        )

# %%
sms = "(PV > anyBSM(1),MET(2))"
sms = ExpSMS.from_string(sms, model=finalStates)
graph_kwargs3={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"}
nodes_kwargs3={'style' : 'filled', 'fontsize' : '15', 'color' : 'black',
                                'shape' : 'circle','margin' : '0'}
edges_kwargs3={'arrowhead' : 'vee', 'arrowsize' : '0.7',  'color' : 'grey53'}
sms.draw(nodes_kwargs=nodes_kwargs3, graph_kwargs=graph_kwargs3,edges_kwargs=edges_kwargs3,
         particleColor='steelblue3',smColor='lightpink3'
#         , filename='sms_tpC3.png'
        )
# Out:
# (eog:12286): Atk-CRITICAL **: 10:13:35.825: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:12286): Gtk-CRITICAL **: 10:13:35.825: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed

# %%
sms = "(PV > gluino(1),gluino(2)), (gluino(1) > N1(3),u~(4),u(5)), (N1(3) > N1(6),Z(7)), (gluino(2) > u~(8),u(9),N1(10)), (N1(10) > Z(11),N1(12))"
sms = ExpSMS.from_string(sms, model=model)
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 'fixedsize' : 'true', 
                           'width' : '0.3', 'height' : '0.3'}

sms.draw(nodes_kwargs=nodes_kwargs2,labelAttr={0 : '', 1 : 'A',2 : 'A', 3 : 'B', 4 : 'q', 5 : 'q', 6 : 'C', 7 : 'Z',
                                              8 : 'q', 9 : 'q', 10 : 'B', 11 : 'Z', 12 : 'C'}
#         ,  filename='sms_tpD1.png'
        )

sms.draw(nodes_kwargs=nodes_kwargs2,labelAttr={0 : '', 1 : "A'",2 : "A'", 3 : "B'", 4 : 'q', 5 : 'q', 6 : 'C', 7 : 'Z',
                                              8 : 'q', 9 : 'q', 10 : "B'", 11 : 'Z', 12 : 'C'}
#         ,  filename='sms_tpD2.png'
        )

nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 'fixedsize' : 'true', 
                           'width' : '0.4', 'height' : '0.4'}

sms.draw(nodes_kwargs=nodes_kwargs2,labelAttr={0 : '', 1 : "A+A'",2 : "A+A'", 3 : "B+B'", 4 : 'q', 5 : 'q', 6 : 'C', 7 : 'Z',
                                              8 : 'q', 9 : 'q', 10 : "B+B'", 11 : 'Z', 12 : 'C'}
#         ,  filename='sms_tpD3.png'
        )

# %% [markdown]
# ## Database Structure

# %%
sms = ExpSMS.from_string('(PV > anyBSM(1),anyBSM(2)), (anyBSM(1) > W,MET(3)), (anyBSM(2) > higgs,MET(4))',model=finalStates)
# sms.draw(filename='TChiWH.png')

# %%
sms = ExpSMS.from_string('(PV > anyBSM(1)), (anyBSM(1) > MET(2),MET(3))',
                         model=finalStates)
nodes_kwargs2={'style' : 'filled', 'fontsize' : '13', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 'fixedsize' : 'false', 
                           'width' : '0.5', 'height' : '0.5'}

sms.draw(nodes_kwargs=nodes_kwargs2,maxLabelSize=0,
         labelAttr={0 : '', 1 : 'A',2 : 'B', 3 : 'C'}
#         ,  filename='sms_Reweight.png'
        )

# %%
sms = ExpSMS.from_string('(PV > anyBSM(1)), (anyBSM(1) > MET(2),MET(3))',
                         model=finalStates)
graph_kwargs3={'layout' : 'dot', 'ranksep' : '0.3', 'rankdir' : "RL"}
nodes_kwargs3={'style' : 'filled', 'fontsize' : '10', 'color' : 'black','fontsize' : '13',
                                'shape' : 'circle','margin' : '0','width' : '0.5', 'height' : '0.5'}
sms.draw(nodes_kwargs=nodes_kwargs3, graph_kwargs=graph_kwargs3,edges_kwargs=edges_kwargs3,
         particleColor='steelblue3',smColor='lightpink3',labelAttr={0 : '', 1 : 'A',2 : 'B', 3 : 'C'}
#         ,  filename='sms_ReweightDB.png'
        )

# %%
sms = ExpSMS.from_string('(PV > anyBSM(1)), (anyBSM(1) > MET(2),MET(3))',
                         model=finalStates)
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 'fixedsize' : 'false', 
                           'width' : '0.2', 'height' : '0.2'}

sms.draw(nodes_kwargs=nodes_kwargs2,maxLabelSize=0,
         labelAttr={0 : '', 1 : '',2 : '', 3 : ''}
        # ,  filename='sms_sms1.png'
        )

sms = ExpSMS.from_string('(PV > anyBSM(1), anyBSM(2)), (anyBSM(1) > MET(3),MET(4))',
                         model=finalStates)
nodes_kwargs2={'style' : 'filled', 'fontsize' : '10', 'color' : 'black',
                                'shape' : 'circle','margin' : '0', 'fixedsize' : 'false', 
                           'width' : '0.2', 'height' : '0.2'}

sms.draw(nodes_kwargs=nodes_kwargs2,maxLabelSize=0,
         labelAttr={0 : '', 1 : '',2 : '', 3 : '', 4 : ''}
        # ,  filename='sms_sms1.png'
        )

# %% [markdown]
# ### Coverage

# %%
from smodels.tools.coverage import FinalStateSMS

# %%
smsA = "(PV > H0(1),H-(2)), (H0(1) > H+(3),H-(4)), (H+(3) > W+,higgs), (H-(4) > W-,higgs), (H-(2) > W-,higgs)"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
    filename='sms_coverage_sms1.png'
)
fsA = FinalStateSMS(smsA,missingX=1.0)
fsA.draw(
    filename='sms_coverage_sms1_simp.png'
)
# Out:
# (eog:12286): Atk-CRITICAL **: 10:13:36.659: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:12286): Gtk-CRITICAL **: 10:13:36.659: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed

# %%
smsA = "(PV > H0(1)), (H0(1) > H-(2),e+,nu)"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
    filename='sms_coverage_sms2.png'
)
fsA = FinalStateSMS(smsA,missingX=1.0)
fsA.draw(
        filename='sms_coverage_sms2_simp.png'
)
# Out:
# (eog:12286): Atk-CRITICAL **: 10:13:36.866: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:12286): Gtk-CRITICAL **: 10:13:36.866: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed

# %%
smsA = "(PV > H0(1)), (H0(1) > H+(2),mu-,nu)"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
    filename='sms_coverage_sms3.png'
)
fsA = FinalStateSMS(smsA,missingX=1.0)
fsA.draw(
        filename='sms_coverage_sms3_simp.png'
)
# Out:
# (eog:12286): Atk-CRITICAL **: 10:13:37.311: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:12286): Gtk-CRITICAL **: 10:13:37.311: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed
# (eog:12286): Atk-CRITICAL **: 10:13:37.486: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:12286): Gtk-CRITICAL **: 10:13:37.486: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed

# %% [markdown]
# ### Paper graphs

# %%
from smodels.share.models.mssm import BSMList
model = Model(BSMList,SMList)
smsA = "(PV > C1+(1),N1(2)), (C1+(1) > q(3),q(4),q(5)), (N1(2) > q(6),q(7),q(8))"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
    # filename='sms_rpv_example1.png'
)

smsA = "(PV > C1+(1),N1(2)), (C1+(1) > q(3),q(4),q(5)), (N1(2) > q(6),q(7),q(8))"
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
    filename='sms_rpv_example2.png', labelAttr = {0: 'PV', 1 : "anyBSM", 2 : 'anyBSM', 
                                                  3 : 'q', 4 : 'q', 5 : 'q', 6 : 'q',
                                                  7 : 'q', 8 : 'q'}
)

# %%
from smodels.base import runtime
from smodels.tools.particlesLoader import load,getParticlesFromSLHA
# Load the BSM model
runtime.modelFile = "../../../../smodels/share/models/zprime.slha"
# BSMList = load()
BSMList = getParticlesFromSLHA(runtime.modelFile)
model = Model(BSMList,SMList)

# %%
smsA = "(PV > zprime(1)), (zprime(1) > dm(2),dm(3))"
# Hack to create a theory element from a string:
smsA = ExpSMS.from_string(smsA, model=model)
smsA.draw(
    filename='sms_zprime_example1.png', labelAttr = {0: 'PV', 1 : "Z'", 2 : 'DM', 3 : 'DM'}
)

smsB = "(PV > zprime(1)), (zprime(1) > q(2),q(3))"
# Hack to create a theory element from a string:
smsB = ExpSMS.from_string(smsB, model=model)
smsB.draw(
    filename='sms_zprime_example2.png', labelAttr = {0: 'PV', 1 : "Z'", 2 : 'q', 3 : 'q'}
)

smsB = "(PV > zprime(1)), (zprime(1) > t+(2),t-(3))"
# Hack to create a theory element from a string:
smsB = ExpSMS.from_string(smsB, model=model)
smsB.draw(
    filename='sms_zprime_example3.png', labelAttr = {0: 'PV', 1 : "Z'", 2 : 'q,b,t', 3 : 'q,b,t'}
)

smsB = "(PV > zprime(1)), (zprime(1) > dm(2),dm(3))"
# Hack to create a theory element from a string:
smsB = ExpSMS.from_string(smsB, model=model)
smsB.draw(
    filename='sms_zprime_example4.png', labelAttr = {0: 'PV', 1 : "Z'/S", 2 : 'DM', 3 : 'DM'}
)
# Out:
# (eog:13438): Atk-CRITICAL **: 10:44:13.918: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:13438): Gtk-CRITICAL **: 10:44:13.918: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed
# (eog:13438): Atk-CRITICAL **: 10:44:14.200: atk_object_ref_state_set: assertion 'ATK_IS_OBJECT (accessible)' failed
#
# (eog:13438): Gtk-CRITICAL **: 10:44:14.200: gtk_accessible_get_widget: assertion 'GTK_IS_ACCESSIBLE (accessible)' failed
