# %%
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from smodels.theory.theorySMS import TheorySMS
from smodels.experiment.expSMS import ExpSMS
from smodels.particlesLoader import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.experiment.defaultFinalStates import finalStates
from smodels.theory.model import Model
from collections import OrderedDict
from smodels.tools.physicsUnits import fb, GeV
import pickle as serializer

# %%
elString = "[[['jet']],[['jet', 'e-'],['nu','e-']]]"
el = ExpSMS.from_string(elString,model=finalStates)

# %%
el.draw()
print(el.nodes)
print(el.edges)
# Out:
# [PV, anyBSM, anyBSM, anyBSM, jet, MET, jet, e-, nu, e-, MET]
# [(PV, anyBSM), (PV, anyBSM), (anyBSM, jet), (anyBSM, MET), (anyBSM, anyBSM), (anyBSM, jet), (anyBSM, e-), (anyBSM, nu), (anyBSM, e-), (anyBSM, MET)]

# %%
testFile = "test_element.pcl"
with open(testFile,"wb") as f:
    serializer.dump(el,f,protocol=4)

# %%
with open(testFile,"rb") as f:
    newEl = serializer.load(f)

# %%
newEl.draw()
print(newEl.nodes)
print(newEl.edges)
# Out:
# [PV, anyBSM, anyBSM, anyBSM, jet, MET, jet, e-, nu, e-, MET]
# [(PV, anyBSM), (PV, anyBSM), (anyBSM, jet), (anyBSM, MET), (anyBSM, anyBSM), (anyBSM, jet), (anyBSM, e-), (anyBSM, nu), (anyBSM, e-), (anyBSM, MET)]
