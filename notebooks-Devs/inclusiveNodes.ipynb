# %%
import sys,time
sys.path.append('../')
from smodels.theory.tree import Tree, InclusiveParticleNode
from smodels.theory.auxiliaryFunctions import bracketToProcessStr
from smodels.experiment.finalStateParticles import finalStates
from smodels.particlesLoader import BSMList
from smodels.share.models.SMparticles import SMList
from smodels.theory.model import Model
from smodels.tools.physicsUnits import fb, GeV
from smodels.theory.element import Element
import networkx as nx

# %% [markdown]
# ### Convert (old) bracket notation with InclusiveBranch

# %%
stringEl = "[ [ ['L','nu'] ], [*] ]"
output = bracketToProcessStr(stringEl)
print(output)
# Out:
# (PV > anyBSM(1),InclusiveNode),(anyBSM(1) > L,nu,MET)

# %%
stringEl = "[ [['*'],['e+']], [ ['L','nu'] ] ]"
output2 = bracketToProcessStr(stringEl)
print(output2)
# Out:
# (PV > anyBSM(1),anyBSM(3)),(anyBSM(1) > anySM,anyBSM(2)),(anyBSM(2) > e+,MET),(anyBSM(3) > L,nu,MET)

# %%
stringEl = "[ [*], [ ['L','nu'] ] ]"
output = bracketToProcessStr(stringEl)
print(output)
# Out:
# (PV > InclusiveNode,anyBSM(1)),(anyBSM(1) > L,nu,MET)

# %% [markdown]
# ### Convert process string to graph

# %%
stringEl = "[ [ ['L','nu'] ], [*] ]"
T = Tree(stringEl)
T.draw()
print(T.nodes)
print(T.edges)
# Out:
# [PV, anyBSM, Inclusive, L, nu, MET]
# [(PV, anyBSM), (PV, Inclusive), (anyBSM, L), (anyBSM, nu), (anyBSM, MET)]

# %%
procString = output2
T = Tree(procString)
T.draw()
print(T.nodes)
print(T.edges)
# Out:
# [PV, anyBSM, anyBSM, anySM, anyBSM, e+, MET, L, nu, MET]
# [(PV, anyBSM), (PV, anyBSM), (anyBSM, anySM), (anyBSM, anyBSM), (anyBSM, L), (anyBSM, nu), (anyBSM, MET), (anyBSM, e+), (anyBSM, MET)]

# %% [markdown]
# ### Create using final states model (database particles)

# %%
stringEl = "[ [['*'],['e+']], [ ['L','nu'] ] ]"
T = Tree(stringEl,model=finalStates)
T.draw()
print(T.nodes)
print(T.edges)
# Out:
# [PV, anyBSM, anyBSM, anySM, anyBSM, e+, MET, L, nu, MET]
# [(PV, anyBSM), (PV, anyBSM), (anyBSM, anySM), (anyBSM, anyBSM), (anyBSM, L), (anyBSM, nu), (anyBSM, MET), (anyBSM, e+), (anyBSM, MET)]

# %%
stringEl = "[ [ ['L','nu'] ], [*] ]"
T = Tree(stringEl,model=finalStates)
T.draw()
print(T.nodes)
print(T.edges)
# Out:
# [PV, anyBSM, Inclusive, L, nu, MET]
# [(PV, anyBSM), (PV, Inclusive), (anyBSM, L), (anyBSM, nu), (anyBSM, MET)]

# %%
T.sort()
T.draw()
print(T.nodes)
print(T.edges)
# Out:
# [PV, Inclusive, anyBSM, nu, L, MET]
# [(PV, Inclusive), (PV, anyBSM), (anyBSM, nu), (anyBSM, L), (anyBSM, MET)]

# %%
for n in T.nodes:
    print(n,n.canonName)
# Out:
# PV *
# Inclusive *
# anyBSM 11010100
# nu 10
# L 10
# MET 10

# %%
stringEl = "[ [*], [ ['L','nu'] ] ]"
output = bracketToProcessStr(stringEl)
procString = output
T = Tree(procString,model=finalStates)
T.sort()
T.draw()
print(T.nodes)
print(T.edges)
# Out:
# [PV, Inclusive, anyBSM, nu, L, MET]
# [(PV, Inclusive), (PV, anyBSM), (anyBSM, nu), (anyBSM, L), (anyBSM, MET)]

# %% [markdown]
# ### Element comparison

# %%
slhafile="../inputFiles/slha/lightEWinos.slha"
model = Model(BSMList,SMList)
model.updateParticles(inputFile=slhafile,promptWidth = 1e-12*GeV)

# %%
elA = Element("[ [ ['e-','nu'] ], [['ta+','ta-'],['u,u~']] ]",model=model,
              intermediateState=[['C1-'],['N2','gluino']], finalState=['N1','N1'])
elB = Element("[ [*], [ ['L','nu'] ] ]",model=finalStates)
elC = Element("[ [ ['e-','q'] ], [['e+','ta-']] ]",model=model,
              intermediateState=[['C1-'],['N2','gluino']], finalState=['N1','C2+'])

# %%
elA.drawTree()
elB.drawTree()
elC.drawTree()

# %%
elA == elB,elC == elB
# Out:
# (True, False)

# %%
matchedEl = elA.compareTo(elB)[1]
matchedEl.drawTree()
print(matchedEl.tree.nodes)
print(matchedEl.tree.edges)
# Out:
# [PV, Inclusive, anyBSM, nu, L, MET]
# [(PV, Inclusive), (PV, anyBSM), (anyBSM, nu), (anyBSM, L), (anyBSM, MET)]

# %%
matchedEl = elB.compareTo(elA)[1]
matchedEl.drawTree()
print(matchedEl.tree.nodes)
print(matchedEl.tree.edges)
# Out:
# [PV, Inclusive, C1-, nu, e-, N1]
# [(PV, Inclusive), (PV, C1-), (C1-, nu), (C1-, e-), (C1-, N1)]

# %%
print(matchedEl.mass)
# Out:
# [None, None, 1.34E+02 [GeV], 0.00E+00 [MeV], 5.00E-01 [MeV], 6.81E+01 [GeV]]

# %%
stringEl = "[ [['*','*']], [ ['L','nu'] ] ]"
elA = Element(stringEl,model=finalStates)
elA.drawTree()
print(elA.tree.nodes)
print(elA.tree.edges)
# Out:
# [PV, anyBSM, anyBSM, nu, L, anySM, anySM, MET, MET]
# [(PV, anyBSM), (PV, anyBSM), (anyBSM, nu), (anyBSM, L), (anyBSM, MET), (anyBSM, anySM), (anyBSM, anySM), (anyBSM, MET)]

# %%
stringEl = "[ [['u','nu']], [ ['e-','nu'] ] ]"
elB = Element(stringEl,model=model,finalState=['N1','N1'],intermediateState=[['gluino'],['gluino']])
elB.drawTree()
print(elB.tree.nodes)
print(elB.tree.edges)
# Out:
# [PV, gluino, gluino, q, nu, nu, e-, N1, N1]
# [(PV, gluino), (PV, gluino), (gluino, q), (gluino, nu), (gluino, N1), (gluino, nu), (gluino, e-), (gluino, N1)]

# %%
elA == elB
# Out:
# True

# %%
stringEl = "[ [['u','nu']], [ ['e-','e+'] ] ]"
elC = Element(stringEl,model=model,finalState=['N1','N1'],intermediateState=[['gluino'],['gluino']])
elC.drawTree()
print(elC.tree.nodes)
print(elC.tree.edges)
# Out:
# [PV, gluino, gluino, q, e+, nu, e-, N1, N1]
# [(PV, gluino), (PV, gluino), (gluino, q), (gluino, nu), (gluino, N1), (gluino, e+), (gluino, e-), (gluino, N1)]

# %%
elA == elC
# Out:
# False
